# %% [markdown]
# # Final Project, Part 3
#
# I stole this template from hw_2

# %% [markdown]
# ### Step 1: Load the python libraries you will need for this project

# %%
#imports
from __future__ import division
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import pylab as pl
import numpy as np
# %matplotlib inline

# %% [markdown]
# ### Step 2: Read in your data set

# %%
#Read in data from source 
df_raw = pd.read_csv("../data/da30811f-f66f-4413-85df-01bee64fc35a_Data.csv")
print df_raw.head()
print df_raw.tail()
print len(df_raw)
# Out:
#                               ﻿Series Name     Series Code  Country Name  \
# 0  Access to electricity (% of population)  EG.ELC.ACCS.ZS        Angola
# 1  Access to electricity (% of population)  EG.ELC.ACCS.ZS         Benin
# 2  Access to electricity (% of population)  EG.ELC.ACCS.ZS      Botswana
# 3  Access to electricity (% of population)  EG.ELC.ACCS.ZS  Burkina Faso
# 4  Access to electricity (% of population)  EG.ELC.ACCS.ZS       Burundi
#
#   Country Code 1960 [YR1960] 1961 [YR1961] 1962 [YR1962] 1963 [YR1963]  \
# 0          AGO            ..            ..            ..            ..
# 1          BEN            ..            ..            ..            ..
# 2          BWA            ..            ..            ..            ..
# 3          BFA            ..            ..            ..            ..
# 4          BDI            ..            ..            ..            ..
#
#   1964 [YR1964] 1965 [YR1965]      ...      2007 [YR2007] 2008 [YR2008]  \
# ...

# %% [markdown]
# ## Questions
# #### Question 1. How many observations are in our dataset?

# %%
df_raw.count()
# Out:
# ﻿Series Name     290
# Series Code      288
# Country Name     288
# Country Code     288
# 1960 [YR1960]    288
# 1961 [YR1961]    288
# 1962 [YR1962]    288
# 1963 [YR1963]    288
# 1964 [YR1964]    288
# 1965 [YR1965]    288
# 1966 [YR1966]    288
# 1967 [YR1967]    288
# 1968 [YR1968]    288
# 1969 [YR1969]    288
# 1970 [YR1970]    288
# 1971 [YR1971]    288
# 1972 [YR1972]    288
# 1973 [YR1973]    288
# 1974 [YR1974]    288
# 1975 [YR1975]    288
# 1976 [YR1976]    288
# 1977 [YR1977]    288
# 1978 [YR1978]    288
# 1979 [YR1979]    288
# 1980 [YR1980]    288
# 1981 [YR1981]    288
# 1982 [YR1982]    288
# 1983 [YR1983]    288
# 1984 [YR1984]    288
# 1985 [YR1985]    288
#                 ...
# 1987 [YR1987]    288
# 1988 [YR1988]    288
# 1989 [YR1989]    288
# 1990 [YR1990]    288
# 1991 [YR1991]    288
# 1992 [YR1992]    288
# 1993 [YR1993]    288
# 1994 [YR1994]    288
# 1995 [YR1995]    288
# 1996 [YR1996]    288
# 1997 [YR1997]    288
# 1998 [YR1998]    288
# ...

# %% [markdown]
# Answer:

# %% [markdown]
# #### Question 2. Create a summary table

# %%
#function

# %%
df_raw.describe()
# Out:
#              ﻿Series Name        Series Code Country Name Country Code  \
# count                 290                288          288          288
# unique                  8                  6           48           48
# top     GDP (current US$)  NY.GDP.PCAP.KD.ZG     Cameroon          SLE
# freq                   48                 48            6            6
#
#        1960 [YR1960] 1961 [YR1961] 1962 [YR1962] 1963 [YR1963] 1964 [YR1964]  \
# count            288           288           288           288           288
# unique            62            92            94            94            94
# top               ..            ..            ..            ..            ..
# freq             226           196           194           194           194
#
#        1965 [YR1965]      ...      2007 [YR2007] 2008 [YR2008] 2009 [YR2009]  \
# count            288      ...                288           288           288
# ...

# %%
df_raw[:3].head()
# Out:
#                               ﻿Series Name     Series Code Country Name  \
# 0  Access to electricity (% of population)  EG.ELC.ACCS.ZS       Angola
# 1  Access to electricity (% of population)  EG.ELC.ACCS.ZS        Benin
# 2  Access to electricity (% of population)  EG.ELC.ACCS.ZS     Botswana
#
#   Country Code 1960 [YR1960] 1961 [YR1961] 1962 [YR1962] 1963 [YR1963]  \
# 0          AGO            ..            ..            ..            ..
# 1          BEN            ..            ..            ..            ..
# 2          BWA            ..            ..            ..            ..
#
#   1964 [YR1964] 1965 [YR1965]      ...      2007 [YR2007] 2008 [YR2008]  \
# 0            ..            ..      ...                 ..            ..
# 1            ..            ..      ...                 ..            ..
# 2            ..            ..      ...                 ..            ..
#
#   2009 [YR2009] 2010 [YR2010] 2011 [YR2011] 2012 [YR2012] 2013 [YR2013]  \
# ...

# %%
df_raw[237:288]
# Out:
#                          ﻿Series Name        Series Code  \
# 237  GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG
# 238  GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG
# 239  GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG
# 240      GDP per capita (current US$)     NY.GDP.PCAP.CD
# 241      GDP per capita (current US$)     NY.GDP.PCAP.CD
# 242      GDP per capita (current US$)     NY.GDP.PCAP.CD
# 243      GDP per capita (current US$)     NY.GDP.PCAP.CD
# 244      GDP per capita (current US$)     NY.GDP.PCAP.CD
# 245      GDP per capita (current US$)     NY.GDP.PCAP.CD
# 246      GDP per capita (current US$)     NY.GDP.PCAP.CD
# 247      GDP per capita (current US$)     NY.GDP.PCAP.CD
# 248      GDP per capita (current US$)     NY.GDP.PCAP.CD
# 249      GDP per capita (current US$)     NY.GDP.PCAP.CD
# 250      GDP per capita (current US$)     NY.GDP.PCAP.CD
# 251      GDP per capita (current US$)     NY.GDP.PCAP.CD
# ...

# %% [markdown]
# #### Question 4. Drop data points with missing data

# %%
drop = df_raw.dropna()
drop
# Out:
#                                 ﻿Series Name     Series Code  \
# 0    Access to electricity (% of population)  EG.ELC.ACCS.ZS
# 1    Access to electricity (% of population)  EG.ELC.ACCS.ZS
# 2    Access to electricity (% of population)  EG.ELC.ACCS.ZS
# 3    Access to electricity (% of population)  EG.ELC.ACCS.ZS
# 4    Access to electricity (% of population)  EG.ELC.ACCS.ZS
# 5    Access to electricity (% of population)  EG.ELC.ACCS.ZS
# 6    Access to electricity (% of population)  EG.ELC.ACCS.ZS
# 7    Access to electricity (% of population)  EG.ELC.ACCS.ZS
# 8    Access to electricity (% of population)  EG.ELC.ACCS.ZS
# 9    Access to electricity (% of population)  EG.ELC.ACCS.ZS
# 10   Access to electricity (% of population)  EG.ELC.ACCS.ZS
# 11   Access to electricity (% of population)  EG.ELC.ACCS.ZS
# 12   Access to electricity (% of population)  EG.ELC.ACCS.ZS
# 13   Access to electricity (% of population)  EG.ELC.ACCS.ZS
# ...

# %%
print len(df_raw)
print len(drop)
# Out:
# 293
# 288

# %%
drop[:48]
# Out:
#                                ﻿Series Name     Series Code  \
# 0   Access to electricity (% of population)  EG.ELC.ACCS.ZS
# 1   Access to electricity (% of population)  EG.ELC.ACCS.ZS
# 2   Access to electricity (% of population)  EG.ELC.ACCS.ZS
# 3   Access to electricity (% of population)  EG.ELC.ACCS.ZS
# 4   Access to electricity (% of population)  EG.ELC.ACCS.ZS
# 5   Access to electricity (% of population)  EG.ELC.ACCS.ZS
# 6   Access to electricity (% of population)  EG.ELC.ACCS.ZS
# 7   Access to electricity (% of population)  EG.ELC.ACCS.ZS
# 8   Access to electricity (% of population)  EG.ELC.ACCS.ZS
# 9   Access to electricity (% of population)  EG.ELC.ACCS.ZS
# 10  Access to electricity (% of population)  EG.ELC.ACCS.ZS
# 11  Access to electricity (% of population)  EG.ELC.ACCS.ZS
# 12  Access to electricity (% of population)  EG.ELC.ACCS.ZS
# 13  Access to electricity (% of population)  EG.ELC.ACCS.ZS
# 14  Access to electricity (% of population)  EG.ELC.ACCS.ZS
# ...

# %% [markdown]
# #### Question 5. Confirm that you dropped the correct data. How can you tell?

# %% [markdown]
# Answer: The length of the variable I instantiated to carry the df with the dropped lines is less than the length of the raw df variable.

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
pd.set_option('display.float_format', lambda x: '{:.2f}'.format(x))
% precision 2
from matplotlib import pyplot as plt
plt.style.use('ggplot')
import seaborn as sns
import statsmodels.api as sm

# %%
drop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 288 entries, 0 to 287
# Data columns (total 61 columns):
# ﻿Series Name     288 non-null object
# Series Code      288 non-null object
# Country Name     288 non-null object
# Country Code     288 non-null object
# 1960 [YR1960]    288 non-null object
# 1961 [YR1961]    288 non-null object
# 1962 [YR1962]    288 non-null object
# 1963 [YR1963]    288 non-null object
# 1964 [YR1964]    288 non-null object
# 1965 [YR1965]    288 non-null object
# 1966 [YR1966]    288 non-null object
# 1967 [YR1967]    288 non-null object
# 1968 [YR1968]    288 non-null object
# 1969 [YR1969]    288 non-null object
# 1970 [YR1970]    288 non-null object
# 1971 [YR1971]    288 non-null object
# 1972 [YR1972]    288 non-null object
# 1973 [YR1973]    288 non-null object
# 1974 [YR1974]    288 non-null object
# 1975 [YR1975]    288 non-null object
# 1976 [YR1976]    288 non-null object
# 1977 [YR1977]    288 non-null object
# ...

# %%
drop.describe()
# Out:
#              ﻿Series Name        Series Code Country Name Country Code  \
# count                 288                288          288          288
# unique                  6                  6           48           48
# top     GDP (current US$)  NY.GDP.PCAP.KD.ZG     Cameroon          SLE
# freq                   48                 48            6            6
#
#        1960 [YR1960] 1961 [YR1961] 1962 [YR1962] 1963 [YR1963] 1964 [YR1964]  \
# count            288           288           288           288           288
# unique            62            92            94            94            94
# top               ..            ..            ..            ..            ..
# freq             226           196           194           194           194
#
#        1965 [YR1965]      ...      2007 [YR2007] 2008 [YR2008] 2009 [YR2009]  \
# count            288      ...                288           288           288
# ...

# %%
accpop = df_raw[:48]

# %%
access = drop[:48]
access
# Out:
#                                ﻿Series Name     Series Code  \
# 0   Access to electricity (% of population)  EG.ELC.ACCS.ZS
# 1   Access to electricity (% of population)  EG.ELC.ACCS.ZS
# 2   Access to electricity (% of population)  EG.ELC.ACCS.ZS
# 3   Access to electricity (% of population)  EG.ELC.ACCS.ZS
# 4   Access to electricity (% of population)  EG.ELC.ACCS.ZS
# 5   Access to electricity (% of population)  EG.ELC.ACCS.ZS
# 6   Access to electricity (% of population)  EG.ELC.ACCS.ZS
# 7   Access to electricity (% of population)  EG.ELC.ACCS.ZS
# 8   Access to electricity (% of population)  EG.ELC.ACCS.ZS
# 9   Access to electricity (% of population)  EG.ELC.ACCS.ZS
# 10  Access to electricity (% of population)  EG.ELC.ACCS.ZS
# 11  Access to electricity (% of population)  EG.ELC.ACCS.ZS
# 12  Access to electricity (% of population)  EG.ELC.ACCS.ZS
# 13  Access to electricity (% of population)  EG.ELC.ACCS.ZS
# 14  Access to electricity (% of population)  EG.ELC.ACCS.ZS
# ...

# %%
access.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48 entries, 0 to 47
# Data columns (total 61 columns):
# ﻿Series Name     48 non-null object
# Series Code      48 non-null object
# Country Name     48 non-null object
# Country Code     48 non-null object
# 1960 [YR1960]    48 non-null object
# 1961 [YR1961]    48 non-null object
# 1962 [YR1962]    48 non-null object
# 1963 [YR1963]    48 non-null object
# 1964 [YR1964]    48 non-null object
# 1965 [YR1965]    48 non-null object
# 1966 [YR1966]    48 non-null object
# 1967 [YR1967]    48 non-null object
# 1968 [YR1968]    48 non-null object
# 1969 [YR1969]    48 non-null object
# 1970 [YR1970]    48 non-null object
# 1971 [YR1971]    48 non-null object
# 1972 [YR1972]    48 non-null object
# 1973 [YR1973]    48 non-null object
# 1974 [YR1974]    48 non-null object
# 1975 [YR1975]    48 non-null object
# 1976 [YR1976]    48 non-null object
# 1977 [YR1977]    48 non-null object
# 1978 [YR1978]    48 non-null object
# ...

# %%
access.describe()
# Out:
#                                    ﻿Series Name     Series Code Country Name  \
# count                                        48              48           48
# unique                                        1               1           48
# top     Access to electricity (% of population)  EG.ELC.ACCS.ZS        Gabon
# freq                                         48              48            1
#
#        Country Code 1960 [YR1960] 1961 [YR1961] 1962 [YR1962] 1963 [YR1963]  \
# count            48            48            48            48            48
# unique           48             1             1             1             1
# top             SLE            ..            ..            ..            ..
# freq              1            48            48            48            48
#
#        1964 [YR1964] 1965 [YR1965]      ...      2007 [YR2007] 2008 [YR2008]  \
# count             48            48      ...                 48            48
# ...

# %%
access.shape
# Out:
# (48, 61)

# %%
a = access.loc(1)
a

# %%
access.tail()
# Out:
#                                ﻿Series Name     Series Code Country Name  \
# 43  Access to electricity (% of population)  EG.ELC.ACCS.ZS     Tanzania
# 44  Access to electricity (% of population)  EG.ELC.ACCS.ZS         Togo
# 45  Access to electricity (% of population)  EG.ELC.ACCS.ZS       Uganda
# 46  Access to electricity (% of population)  EG.ELC.ACCS.ZS       Zambia
# 47  Access to electricity (% of population)  EG.ELC.ACCS.ZS     Zimbabwe
#
#    Country Code 1960 [YR1960] 1961 [YR1961] 1962 [YR1962] 1963 [YR1963]  \
# 43          TZA            ..            ..            ..            ..
# 44          TGO            ..            ..            ..            ..
# 45          UGA            ..            ..            ..            ..
# 46          ZMB            ..            ..            ..            ..
# 47          ZWE            ..            ..            ..            ..
#
#    1964 [YR1964] 1965 [YR1965]      ...      2007 [YR2007] 2008 [YR2008]  \
# ...

# %%
access.set_index('Country Name', inplace=True)
access.tail()
# Out:
#                                          ﻿Series Name     Series Code  \
# Country Name
# Tanzania      Access to electricity (% of population)  EG.ELC.ACCS.ZS
# Togo          Access to electricity (% of population)  EG.ELC.ACCS.ZS
# Uganda        Access to electricity (% of population)  EG.ELC.ACCS.ZS
# Zambia        Access to electricity (% of population)  EG.ELC.ACCS.ZS
# Zimbabwe      Access to electricity (% of population)  EG.ELC.ACCS.ZS
#
#              Country Code 1960 [YR1960] 1961 [YR1961] 1962 [YR1962]  \
# Country Name
# Tanzania              TZA            ..            ..            ..
# Togo                  TGO            ..            ..            ..
# Uganda                UGA            ..            ..            ..
# Zambia                ZMB            ..            ..            ..
# Zimbabwe              ZWE            ..            ..            ..
#
#              1963 [YR1963] 1964 [YR1964] 1965 [YR1965] 1966 [YR1966]  \
# Country Name
# ...

# %%
b = pd.melt(access)
b
# Out:
#            variable                                    value
# 0      ﻿Series Name  Access to electricity (% of population)
# 1      ﻿Series Name  Access to electricity (% of population)
# 2      ﻿Series Name  Access to electricity (% of population)
# 3      ﻿Series Name  Access to electricity (% of population)
# 4      ﻿Series Name  Access to electricity (% of population)
# 5      ﻿Series Name  Access to electricity (% of population)
# 6      ﻿Series Name  Access to electricity (% of population)
# 7      ﻿Series Name  Access to electricity (% of population)
# 8      ﻿Series Name  Access to electricity (% of population)
# 9      ﻿Series Name  Access to electricity (% of population)
# 10     ﻿Series Name  Access to electricity (% of population)
# 11     ﻿Series Name  Access to electricity (% of population)
# 12     ﻿Series Name  Access to electricity (% of population)
# 13     ﻿Series Name  Access to electricity (% of population)
# ...

# %%
b[40:]
# Out:
#            variable                                    value
# 40     ﻿Series Name  Access to electricity (% of population)
# 41     ﻿Series Name  Access to electricity (% of population)
# 42     ﻿Series Name  Access to electricity (% of population)
# 43     ﻿Series Name  Access to electricity (% of population)
# 44     ﻿Series Name  Access to electricity (% of population)
# 45     ﻿Series Name  Access to electricity (% of population)
# 46     ﻿Series Name  Access to electricity (% of population)
# 47     ﻿Series Name  Access to electricity (% of population)
# 48      Series Code                           EG.ELC.ACCS.ZS
# 49      Series Code                           EG.ELC.ACCS.ZS
# 50      Series Code                           EG.ELC.ACCS.ZS
# 51      Series Code                           EG.ELC.ACCS.ZS
# 52      Series Code                           EG.ELC.ACCS.ZS
# 53      Series Code                           EG.ELC.ACCS.ZS
# ...

# %%
df_accpop = pd.melt(accpop, id_vars=['Country Name'], value_vars=['1990 [YR1990]','2000 [YR2000]','2010 [YR2010]','2012 [YR2012]'])
df_accpop
# Out:
#                  Country Name       variable     value
# 0                      Angola  1990 [YR1990]  28.21566
# 1                       Benin  1990 [YR1990]  22.03774
# 2                    Botswana  1990 [YR1990]  36.71566
# 3                Burkina Faso  1990 [YR1990]       6.1
# 4                     Burundi  1990 [YR1990]       0.1
# 5                  Cabo Verde  1990 [YR1990]  58.18774
# 6                    Cameroon  1990 [YR1990]        29
# 7    Central African Republic  1990 [YR1990]         3
# 8                        Chad  1990 [YR1990]       0.1
# 9                     Comoros  1990 [YR1990]  41.95982
# 10           Congo, Dem. Rep.  1990 [YR1990]   6.33774
# 11                Congo, Rep.  1990 [YR1990]  24.38774
# 12              Cote d'Ivoire  1990 [YR1990]      36.5
# 13          Equatorial Guinea  1990 [YR1990]  56.89426
# 14                    Eritrea  1990 [YR1990]      22.9
# 15                   Ethiopia  1990 [YR1990]        10
# ...

# %%
gdp = df_raw[144:192]
gdp
# Out:
#           ﻿Series Name     Series Code              Country Name Country Code  \
# 144  GDP (current US$)  NY.GDP.MKTP.CD                    Angola          AGO
# 145  GDP (current US$)  NY.GDP.MKTP.CD                     Benin          BEN
# 146  GDP (current US$)  NY.GDP.MKTP.CD                  Botswana          BWA
# 147  GDP (current US$)  NY.GDP.MKTP.CD              Burkina Faso          BFA
# 148  GDP (current US$)  NY.GDP.MKTP.CD                   Burundi          BDI
# 149  GDP (current US$)  NY.GDP.MKTP.CD                Cabo Verde          CPV
# 150  GDP (current US$)  NY.GDP.MKTP.CD                  Cameroon          CMR
# 151  GDP (current US$)  NY.GDP.MKTP.CD  Central African Republic          CAF
# 152  GDP (current US$)  NY.GDP.MKTP.CD                      Chad          TCD
# 153  GDP (current US$)  NY.GDP.MKTP.CD                   Comoros          COM
# 154  GDP (current US$)  NY.GDP.MKTP.CD          Congo, Dem. Rep.          ZAR
# ...

# %%
df_gdp = pd.melt(gdp, id_vars=['Country Name'], value_vars=['1990 [YR1990]','2000 [YR2000]','2010 [YR2010]','2012 [YR2012]'])
df_gdp
# Out:
#                  Country Name       variable             value
# 0                      Angola  1990 [YR1990]  10027408249.2145
# 1                       Benin  1990 [YR1990]  1959965330.47596
# 2                    Botswana  1990 [YR1990]  3790636664.02546
# 3                Burkina Faso  1990 [YR1990]  3101300779.08364
# 4                     Burundi  1990 [YR1990]  1132101252.51817
# 5                  Cabo Verde  1990 [YR1990]  306891107.262039
# 6                    Cameroon  1990 [YR1990]  11151578702.7205
# 7    Central African Republic  1990 [YR1990]    1440711459.411
# 8                        Chad  1990 [YR1990]  1738605558.05436
# 9                     Comoros  1990 [YR1990]   250030778.38846
# 10           Congo, Dem. Rep.  1990 [YR1990]                 0
# 11                Congo, Rep.  1990 [YR1990]  2798746050.58236
# 12              Cote d'Ivoire  1990 [YR1990]  10795850584.5874
# 13          Equatorial Guinea  1990 [YR1990]  112119406.548331
# ...

# %%
#this is our working df!! a/o 12/6/16
joined = df_accpop.join(df_gdp['value'], lsuffix='_access', rsuffix='_gdp')
joined
# Out:
#                  Country Name       variable value_access         value_gdp
# 0                      Angola  1990 [YR1990]     28.21566  10027408249.2145
# 1                       Benin  1990 [YR1990]     22.03774  1959965330.47596
# 2                    Botswana  1990 [YR1990]     36.71566  3790636664.02546
# 3                Burkina Faso  1990 [YR1990]          6.1  3101300779.08364
# 4                     Burundi  1990 [YR1990]          0.1  1132101252.51817
# 5                  Cabo Verde  1990 [YR1990]     58.18774  306891107.262039
# 6                    Cameroon  1990 [YR1990]           29  11151578702.7205
# 7    Central African Republic  1990 [YR1990]            3    1440711459.411
# 8                        Chad  1990 [YR1990]          0.1  1738605558.05436
# 9                     Comoros  1990 [YR1990]     41.95982   250030778.38846
# 10           Congo, Dem. Rep.  1990 [YR1990]      6.33774                 0
# ...

# %%
benin = joined[joined['Country Name'] == 'Benin']
benin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4 entries, 1 to 145
# Data columns (total 4 columns):
# Country Name    4 non-null object
# variable        4 non-null object
# value_access    4 non-null object
# value_gdp       4 non-null object
# dtypes: object(4)
# memory usage: 160.0+ bytes

# %%
#stealing from class 16 solution code

import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from pylab import rcParams
rcParams['figure.figsize'] = 13, 5

# %%
#joined_int = int(joined['value_access']) 
 
joined['value_access'] = [float(x) for x in joined['value_access']]
joined.info(())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 192 entries, 0 to 191
# Data columns (total 4 columns):
# Country Name    192 non-null object
# variable        192 non-null object
# value_access    192 non-null float64
# value_gdp       192 non-null object
# dtypes: float64(1), object(3)
# memory usage: 6.1+ KB

# %%
joined.plot()

# %%
joined[joined['Country Name'] == 'Benin'].plot()

# %%
benin.plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-f3227707c75a> in <module>()
# ----> 1 benin.plot()
#
# /Users/craig.wood/anaconda/lib/python2.7/site-packages/pandas/tools/plotting.pyc in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    3738                           fontsize=fontsize, colormap=colormap, table=table,
#    3739                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 3740                           sort_columns=sort_columns, **kwds)
#    3741     __call__.__doc__ = plot_frame.__doc__
#    3742
#
# ...

# %%
benin.head()
# Out:
#     Country Name       variable value_access         value_gdp
# 1          Benin  1990 [YR1990]     22.03774  1959965330.47596
# 49         Benin  2000 [YR2000]         25.4  2569186642.86999
# 97         Benin  2010 [YR2010]         27.9  6970240895.49888
# 145        Benin  2012 [YR2012]         38.4  8117100933.52537

# %%
benin.plot(x=benin['variable'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-6c62550eb42a> in <module>()
# ----> 1 benin.plot(x=benin['variable'])
#
# /Users/craig.wood/anaconda/lib/python2.7/site-packages/pandas/tools/plotting.pyc in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    3738                           fontsize=fontsize, colormap=colormap, table=table,
#    3739                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 3740                           sort_columns=sort_columns, **kwds)
#    3741     __call__.__doc__ = plot_frame.__doc__
#    3742
#
# ...

# %%
joined.plot(x=joined['variable'])

# %%
joined['variable'] = [x[0:4] for x in joined['variable']]
pd.to_datetime(joined['variable'])
# Out:
# 0     1990-01-01
# 1     1990-01-01
# 2     1990-01-01
# 3     1990-01-01
# 4     1990-01-01
# 5     1990-01-01
# 6     1990-01-01
# 7     1990-01-01
# 8     1990-01-01
# 9     1990-01-01
# 10    1990-01-01
# 11    1990-01-01
# 12    1990-01-01
# 13    1990-01-01
# 14    1990-01-01
# 15    1990-01-01
# 16    1990-01-01
# 17    1990-01-01
# 18    1990-01-01
# 19    1990-01-01
# 20    1990-01-01
# 21    1990-01-01
# 22    1990-01-01
# 23    1990-01-01
# 24    1990-01-01
# 25    1990-01-01
# 26    1990-01-01
# 27    1990-01-01
# 28    1990-01-01
# 29    1990-01-01
#          ...
# 162   2012-01-01
# 163   2012-01-01
# 164   2012-01-01
# 165   2012-01-01
# 166   2012-01-01
# 167   2012-01-01
# 168   2012-01-01
# 169   2012-01-01
# 170   2012-01-01
# 171   2012-01-01
# 172   2012-01-01
# 173   2012-01-01
# 174   2012-01-01
# 175   2012-01-01
# 176   2012-01-01
# 177   2012-01-01
# 178   2012-01-01
# 179   2012-01-01
# 180   2012-01-01
# 181   2012-01-01
# 182   2012-01-01
# ...

# %%
joined.plot(x=joined['variable'])

# %%
joined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 192 entries, 0 to 191
# Data columns (total 4 columns):
# Country Name    192 non-null object
# variable        192 non-null object
# value_access    192 non-null float64
# value_gdp       192 non-null object
# dtypes: float64(1), object(3)
# memory usage: 6.1+ KB

# %%
joined['value_gdp'] = joined['value_gdp'].convert_objects(convert_numeric=True)
# Out:
# /Users/craig.wood/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   if __name__ == '__main__':

# %%
joined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 192 entries, 0 to 191
# Data columns (total 4 columns):
# Country Name    192 non-null object
# variable        192 non-null object
# value_access    192 non-null float64
# value_gdp       182 non-null float64
# dtypes: float64(2), object(2)
# memory usage: 6.1+ KB

# %%
joined.plot(x=joined['variable'])

# %%
benin = joined[joined['Country Name'] == 'Benin']
benin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4 entries, 1 to 145
# Data columns (total 4 columns):
# Country Name    4 non-null object
# variable        4 non-null object
# value_access    4 non-null float64
# value_gdp       4 non-null float64
# dtypes: float64(2), object(2)
# memory usage: 160.0+ bytes

# %%
benin.plot(x=benin['variable'])

# %%
joined.plot(x=joined['variable'])

# %%
joined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 192 entries, 28.21566 to 40.46256
# Data columns (total 3 columns):
# Country Name    192 non-null object
# variable        192 non-null object
# value_gdp       182 non-null float64
# dtypes: float64(1), object(2)
# memory usage: 6.0+ KB

# %%
joined.set_index('value_access', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-63-c8a3d1bb1f11> in <module>()
# ----> 1 joined.set_index(joined['value_access'], inplace=True)
#
# /Users/craig.wood/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1995             return self._getitem_multilevel(key)
#    1996         else:
# -> 1997             return self._getitem_column(key)
#    1998
#    1999     def _getitem_column(self, key):
#
# /Users/craig.wood/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2002         # get column
#    2003         if self.columns.is_unique:
# -> 2004             return self._get_item_cache(key)
#    2005
#    2006         # duplicate columns & possible reduce dimensionality
#
# ...

# %%
joined.head()
# Out:
#               Country Name variable      value_gdp
# value_access
# 28.22               Angola     1990 10027408249.21
# 22.04                Benin     1990  1959965330.48
# 36.72             Botswana     1990  3790636664.03
# 6.10          Burkina Faso     1990  3101300779.08
# 0.10               Burundi     1990  1132101252.52

# %%
joined.plot(x=joined['variable'])

# %%
benin.set_index('value_access', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-68-d02df82ccc8a> in <module>()
# ----> 1 benin.set_index('value_access', inplace=True)
#       2 benin.plot(x=benin['variable'])
#
# /Users/craig.wood/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in set_index(self, keys, drop, append, inplace, verify_integrity)
#    2835                 names.append(None)
#    2836             else:
# -> 2837                 level = frame[col]._values
#    2838                 names.append(col)
#    2839                 if drop:
#
# /Users/craig.wood/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1995             return self._getitem_multilevel(key)
#    1996         else:
# -> 1997             return self._getitem_column(key)
#    1998
#    1999     def _getitem_column(self, key):
#
# ...

# %%
benin.plot()

# %%
benin.head()
# Out:
#              Country Name variable     value_gdp
# value_access
# 22.04               Benin     1990 1959965330.48
# 25.40               Benin     2000 2569186642.87
# 27.90               Benin     2010 6970240895.50
# 38.40               Benin     2012 8117100933.53

# %%
angola = joined[joined ['Country Name'] == 'Angola']

angola.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 4 entries, 28.21566 to 37.0
# Data columns (total 3 columns):
# Country Name    4 non-null object
# variable        4 non-null object
# value_gdp       4 non-null float64
# dtypes: float64(1), object(2)
# memory usage: 128.0+ bytes

# %%
join = df_accpop.join(df_gdp['value'], lsuffix='_access', rsuffix='_gdp')
join
# Out:
#                  Country Name       variable value_access         value_gdp
# 0                      Angola  1990 [YR1990]     28.21566  10027408249.2145
# 1                       Benin  1990 [YR1990]     22.03774  1959965330.47596
# 2                    Botswana  1990 [YR1990]     36.71566  3790636664.02546
# 3                Burkina Faso  1990 [YR1990]          6.1  3101300779.08364
# 4                     Burundi  1990 [YR1990]          0.1  1132101252.51817
# 5                  Cabo Verde  1990 [YR1990]     58.18774  306891107.262039
# 6                    Cameroon  1990 [YR1990]           29  11151578702.7205
# 7    Central African Republic  1990 [YR1990]            3    1440711459.411
# 8                        Chad  1990 [YR1990]          0.1  1738605558.05436
# 9                     Comoros  1990 [YR1990]     41.95982   250030778.38846
# 10           Congo, Dem. Rep.  1990 [YR1990]      6.33774                 0
# ...

# %%
join['value_gdp'] = join['value_gdp'].convert_objects(convert_numeric=True)
join['value_access'] = join['value_access'].convert_objects(convert_numeric=True)
# Out:
# /Users/craig.wood/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   if __name__ == '__main__':
# /Users/craig.wood/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   from ipykernel import kernelapp as app

# %%
join.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 192 entries, 0 to 191
# Data columns (total 4 columns):
# Country Name    192 non-null object
# variable        192 non-null object
# value_access    192 non-null float64
# value_gdp       182 non-null float64
# dtypes: float64(2), object(2)
# memory usage: 6.1+ KB

# %%
join.plot()

# %%
join['variable'] = [x[0:4] for x in join['variable']]
pd.to_datetime(join['variable'])
# Out:
# 0     1990-01-01
# 1     1990-01-01
# 2     1990-01-01
# 3     1990-01-01
# 4     1990-01-01
# 5     1990-01-01
# 6     1990-01-01
# 7     1990-01-01
# 8     1990-01-01
# 9     1990-01-01
# 10    1990-01-01
# 11    1990-01-01
# 12    1990-01-01
# 13    1990-01-01
# 14    1990-01-01
# 15    1990-01-01
# 16    1990-01-01
# 17    1990-01-01
# 18    1990-01-01
# 19    1990-01-01
# 20    1990-01-01
# 21    1990-01-01
# 22    1990-01-01
# 23    1990-01-01
# 24    1990-01-01
# 25    1990-01-01
# 26    1990-01-01
# 27    1990-01-01
# 28    1990-01-01
# 29    1990-01-01
#          ...
# 162   2012-01-01
# 163   2012-01-01
# 164   2012-01-01
# 165   2012-01-01
# 166   2012-01-01
# 167   2012-01-01
# 168   2012-01-01
# 169   2012-01-01
# 170   2012-01-01
# 171   2012-01-01
# 172   2012-01-01
# 173   2012-01-01
# 174   2012-01-01
# 175   2012-01-01
# 176   2012-01-01
# 177   2012-01-01
# 178   2012-01-01
# 179   2012-01-01
# 180   2012-01-01
# 181   2012-01-01
# 182   2012-01-01
# ...

# %%
join.head()
# Out:
#    Country Name variable  value_access      value_gdp
# 0        Angola     1990         28.22 10027408249.21
# 1         Benin     1990         22.04  1959965330.48
# 2      Botswana     1990         36.72  3790636664.03
# 3  Burkina Faso     1990          6.10  3101300779.08
# 4       Burundi     1990          0.10  1132101252.52

# %%
by_country = join.groupby('Country Name')

# %%
DataFrameGroupBy.plot(join)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-98-667073f341fd> in <module>()
# ----> 1 DataFrameGroupBy.plot(join)
#
# NameError: name 'DataFrameGroupBy' is not defined

# %%
import seaborn as sb
# %matplotlib inline

# %%
sb.factorplot(
    col='Country Name',
    x='variable',
    y='value_access',
    data=join,
    kind='box'
);

# %%
sb.factorplot(
    col='Country Name',
    x='variable',
    y='value_access',
    data=join,
    kind='bar'
);

# %%
sb.factorplot(
    col='Country Name',
    x='variable',
    y='value_gdp',
    data=join,
    kind='bar'
);

# %%
sb.factorplot(
    col='Country Name',
    x='variable',
    y='value_access',
    data=join,
    kind='point'
);

# %%
sb.factorplot(
    col='Country Name',
    x='variable',
    y='value_access',
    data=join,
    kind='strip'
);

# %%
#we want to find the top 5 countries that had the greatest growth in Access
#we want to find the top 5 countries that had the greatest growth in GDP
#maybe what we do is find the difference between 1990 value_access and 2012 value_access,
#list then from greatest to least
#once we have our top 5 of each Access and GDP, we see if the Top 5 align

# %%
#focusing on Access before turning back to GDP

#joined['value_gdp'] = [float(x) for x in joined['value_gdp']]
#joined.info()

# %%
drop.tail()

# %%
#now working off of Class 15 Time Series
drop.set_index('Country Name', inplace=True)
drop.head()

# %%
drop.Date[0]

# %%
#get dummies for year
#b = pd.get_dummies(access, prefix='year')
#b

# %%
#a = pd.crosstab(access['Country Name'],access['Series Code'])
#a

# %% [markdown]
# #### Question 6. Create box plots for GRE and GPA

# %%
#boxplot 1

# %%
#boxplot 2

# %% [markdown]
# #### Question 7. What do this plots show?

# %% [markdown]
# Answer:

# %% [markdown]
# #### Question 8. Describe each distribution

# %%
# plot the distribution of each variable

# %% [markdown]
# #### Question 9.  If our model had an assumption of a normal distribution would we meet that requirement?

# %% [markdown]
# Answer:

# %% [markdown]
# #### Question 10.  Does this distribution need correction? If so, why? How?

# %% [markdown]
# Answer:

# %% [markdown]
# #### Question 11. Which of our variables are potentially colinear?

# %%
# create a correlation matrix for the data

# %% [markdown]
# #### Question 12. What did you find?

# %% [markdown]
# Answer:

# %% [markdown]
# #### Question 13. Write an analysis plan for exploring the association between grad school admissions rates and prestige of  undergraduate schools.

# %% [markdown]
# Answer:

# %% [markdown]
# #### Question 14. What is your hypothesis?

# %% [markdown]
# Answer:

# %% [markdown]
# ## Bonus/Advanced

# %% [markdown]
# #### 1. Bonus: Explore alternatives to dropping obervations with missing data

# %% [markdown]
# #### 2. Bonus: Log transform the skewed data

# %% [markdown]
# #### 3. Advanced: Impute missing data
